# %% [markdown]
# # Ex2 - Getting and Knowing your Data

# %% [markdown]
# This time we are going to pull data directly from the internet.
# Special thanks to: https://github.com/justmarkham for sharing the dataset and materials.
#
# ### Step 1. Import the necessary libraries

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### Step 2. Import the dataset from this [address](https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv).

# %%
chipo = pd.read_excel("/kaggle/input/chipotle/chipotle_sample_data.xlsx")

# %% [markdown]
# ### Step 3. Assign it to a variable called chipo.

# %%
chipo.head()
# Out:
#    order_id            item_name  quantity  item_price
# 0         1         Chicken Bowl         2        8.49
# 1         2        Steak Burrito         1        9.25
# 2         3         Chicken Bowl         1        8.49
# 3         4  Chips and Guacamole         2        4.45
# 4         5         Chicken Bowl         1        8.49

# %% [markdown]
# ### Step 4. See the first 10 entries

# %%
chipo.head(10)
# Out:
#    order_id            item_name  quantity  item_price
# 0         1         Chicken Bowl         2        8.49
# 1         2        Steak Burrito         1        9.25
# 2         3         Chicken Bowl         1        8.49
# 3         4  Chips and Guacamole         2        4.45
# 4         5         Chicken Bowl         1        8.49
# 5         6        Steak Burrito         2        9.25
# 6         7         Veggie Salad         1        7.00
# 7         8         Chicken Bowl         1        8.49
# 8         9  Chips and Guacamole         3        4.45
# 9        10        Steak Burrito         1        9.25

# %% [markdown]
# ### Step 5. What is the number of observations in the dataset?

# %%
# Solution 1
chipo.shape
# Out:
# (10, 4)

# %%
# Solution 2
len(chipo)
# Out:
# 10

# %% [markdown]
# ### Step 6. What is the number of columns in the dataset?

# %%
len(chipo.columns)
# Out:
# 4

# %% [markdown]
# ### Step 7. Print the name of all the columns.

# %%
chipo.columns
# Out:
# Index(['order_id', 'item_name', 'quantity', 'item_price'], dtype='object')

# %% [markdown]
# ### Step 8. How is the dataset indexed?

# %%
chipo.index
# Out:
# RangeIndex(start=0, stop=10, step=1)

# %% [markdown]
# ### Step 9. Which was the most-ordered item?

# %%
chipo.groupby('item_name')['quantity'].sum().sort_values(ascending=False).head(1)
# Out:
# item_name
# Chicken Bowl    5
# Name: quantity, dtype: int64

# %% [markdown]
# ### Step 10. For the most-ordered item, how many items were ordered?

# %%
ordered = chipo.groupby('item_name')['quantity'].sum().idxmax()
print(ordered)
# Out:
# Chicken Bowl

# %% [markdown]
# ### Step 11. What was the most ordered item in the choice_description column?

# %%
chipo['item_price'].value_counts().head(1)
# Out:
# item_price
# 8.49    4
# Name: count, dtype: int64

# %% [markdown]
# ### Step 12. How many items were orderd in total?

# %%
chipo['quantity'].sum()
# Out:
# 15

# %% [markdown]
# ### Step 13. Turn the item price into a float

# %% [markdown]
# #### Step 13.a. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# #### Step 13.b. Create a lambda function and change the type of item price

# %%
chipo['item_price'] = chipo['item_price'].apply(lambda x: float(str(x).replace('$', '')))

# %% [markdown]
# #### Step 13.c. Check the item price type

# %%
chipo['item_price'].dtype
# Out:
# dtype('float64')

# %% [markdown]
# ### Step 14. How much was the revenue for the period in the dataset?

# %%
revenue = (chipo['quantity'] * chipo['item_price']).sum()
print(revenue)
# Out:
# 108.70000000000002

# %% [markdown]
# ### Step 15. How many orders were made in the period?

# %%
orders = chipo['order_id'].nunique()
print(orders)
# Out:
# 10

# %% [markdown]
# ### Step 16. What is the average revenue amount per order?

# %%
# Solution 1

chipo['total_price'] = chipo['quantity'] * chipo['item_price']
order_revenue = chipo.groupby('order_id')['total_price'].sum()
average_revenue = order_revenue.mean()
print(average_revenue)
# Out:
# 10.870000000000001

# %%
# Solution 2
#meannnn
average_revenue = (chipo['quantity'] * chipo['item_price']).groupby(chipo['order_id']).sum().mean()
print(average_revenue)
# Out:
# 10.870000000000001

# %% [markdown]
# ### Step 17. How many different items are sold?

# %%
count_items = chipo['item_name'].nunique()
print(count_items)
# Out:
# 4
